# %% [markdown]
# # GPT-2 Playground
#
# ## Background
# In this Jupyter notebook you can play around with the small version of **Open AI's GPT-2** Model from the paper *[Language Models are Unsupervised Multitask Learners](https://d4mucfpksywv.cloudfront.net/better-language-models/language-models.pdf).*
#
# According to the authors, the GPT-2 algorithm was trained on the task of *language modeling*--- which tests a program's ability to predict the next word in a given sentence--by ingesting huge numbers of articles, blogs, and websites. By using just this data it achieved state-of-the-art scores on a number of unseen language tests, an achievement known as *zero-shot learning.* It can also perform other writing-related tasks, like translating text from one language to another, summarizing long articles, and answering trivia questions.
#
# Open AI decided not to release the dataset, training code, or the full GPT-2 model weights. This is due to the concerns about large language models being used to generate deceptive, biased, or abusive language at scale. Some examples of the applications of these models for malicious purposes are:
# * Generate misleading news articles
# * Impersonate others online
# * Automate the production of abusive or faked content to post on social media
# * Automate the production of spam/phishing content
#
# As one can imagine, this combined with recent advances in generation of synthetic imagery, audio, and video implies that it's never been easier to create fake content and spread disinformation at scale. The public at large will need to become more skeptical of the content they consume online.
#
# ## Steps
# Before starting, is recommended to set *Runtime Type* to *GPU* on the top menu bar.
#
#
# ###1. Installation
# Download the model data and istall Python libraries:

# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !sh download_model.sh 117M
# !pip3 install -r requirements.txt
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Unpacking objects: 100% (70/70), done.
# Copying gs://gpt-2/models/117M/checkpoint...
# / [1 files][   77.0 B/   77.0 B]
# Operation completed over 1 objects/77.0 B.
# Copying gs://gpt-2/models/117M/encoder.json...
# / [1 files][ 1017 KiB/ 1017 KiB]
# Operation completed over 1 objects/1017.9 KiB.
# Copying gs://gpt-2/models/117M/hparams.json...
# / [1 files][   90.0 B/   90.0 B]
# Operation completed over 1 objects/90.0 B.
# Copying gs://gpt-2/models/117M/model.ckpt.data-00000-of-00001...
# | [1 files][474.7 MiB/474.7 MiB]
# Operation completed over 1 objects/474.7 MiB.
# Copying gs://gpt-2/models/117M/model.ckpt.index...
# / [1 files][  5.1 KiB/  5.1 KiB]
# Operation completed over 1 objects/5.1 KiB.
# Copying gs://gpt-2/models/117M/model.ckpt.meta...
# / [1 files][460.1 KiB/460.1 KiB]
# Operation completed over 1 objects/460.1 KiB.
# Copying gs://gpt-2/models/117M/vocab.bpe...
# / [1 files][445.6 KiB/445.6 KiB]
# Operation completed over 1 objects/445.6 KiB.
# Collecting fire>=0.1.3 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5a/b7/205702f348aab198baecd1d8344a90748cb68f53bdcd1cc30cbc08e47d3e/fire-0.1.3.tar.gz
# Requirement already satisfied: tensorflow>=1.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.13.0rc1)
# Collecting regex==2017.4.5 (from -r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#     100% |████████████████████████████████| 604kB 8.7MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.12.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.33.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.13.0rc0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.14.6)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow>=1.12->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow>=1.12->-r requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow>=1.12->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0rc0->tensorflow>=1.12->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow>=1.12->-r requirements.txt (line 2)) (40.8.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0rc0->tensorflow>=1.12->-r requirements.txt (line 2)) (5.1.2)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/2a/1a/4d/6b30377c3051e76559d1185c1dbbfff15aed31f87acdd14c22
#   Building wheel for regex (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# spacy 2.0.18 has requirement regex==2018.01.10, but you'll have regex 2017.4.5 which is incompatible.
# Installing collected packages: fire, regex
#   Found existing installation: regex 2018.1.10
#     Uninstalling regex-2018.1.10:
#       Successfully uninstalled regex-2018.1.10
# Successfully installed fire-0.1.3 regex-2017.4.5

# %% [markdown]
# ###  2. Unconditional sample generation
#
# WARNING: Samples are unfiltered and may contain offensive content.
#
# To generate unconditional samples from the small model:
# ```
# !python3 src/generate_unconditional_samples.py
# ```
# There are a few flags available.
# - `nsamples`: specify the number of samples you want to print
# - `length`
# - `batch_size`
# - `temperature`
# - `top_k`

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=40 --temperature=0.7 | tee samples
# Out:
# 2019-02-18 09:26:23.465204: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-18 09:26:23.465567: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d24f20 executing computations on platform Host. Devices:
# 2019-02-18 09:26:23.465603: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-18 09:26:23.583330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-18 09:26:23.583883: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d24c60 executing computations on platform CUDA. Devices:
# 2019-02-18 09:26:23.583927: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-18 09:26:23.584265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-18 09:26:23.584300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-18 09:26:24.618637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-18 09:26:24.618713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-18 09:26:24.618732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-18 09:26:24.619011: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-18 09:26:24.619102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-02-18 09:26:30.392997: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
# "There are three types of guns in the world, and one is for self-defense."
#
# This is a quote from the National Rifle Association's executive director, James B. Comey.
#
# "The other is for self-defense," Comey said at the NRA's annual convention in Las Vegas.
#
# "The third type of gun is for self-defense," he said.
#
# The NRA's national executive committee is the same organization that had its first meeting in September.
#
# The conference also included representatives from the National Rifle Association, including then-presidential nominee Donald Trump.
#
# The NRA does not hold its annual convention in Las Vegas.
#
# James B. Comey, National Rifle Association, speaks during a NRA annual convention in Las Vegas. (Photo: Eric Gay/The Republic)
#
# James Comey, a former FBI director, was asked about the 2016 presidential election in July. He said he was unaware of a potential 2016 presidential campaign.
#
# He said he thought he had a better shot at being president.
#
# "I thought that I could get the nomination if I wanted to," Comey said in an interview with The Washington Post. "But I didn't think this was the chance to do it. It's a very difficult thing to do."
#
# Read or Share this story: http://usat.ly/2l0XhFt<|endoftext|>This is a rush transcript. Copy may not be in its final form.
#
# JUAN GONZÁLEZ: I'm Juan Gónaz, and I'm here with a discussion from the Capitol Hill office. Last week, President Barack Obama was in Washington to give a speech on the economy and jobs. And this is the first time he'll address the nation in this manner since the election of George W. Bush. And the president's speech was at the Capitol Hill office and he talked about the economy.
#
# PRESIDENT BARACK OBAMA: It doesn't matter, the economy doesn't matter. It's very important. It's very important. That's why I'm here today and I'm going to go into some detail about the jobs that are coming in the United States today. And my first priority is to make sure we're making sure that we're building the kind of jobs that we need to build so that we can compete for the jobs that we need.
#
# So, I want to do more than just talk about the economy. I want to talk about jobs, about the economy that we're creating, and about the jobs that we're bringing back.
#
# I want to talk about our role as a country. As a country, we need to be investing in our military. We need to invest in our defense. We need to spend more on our military, and I'm going to be doing everything I can to make sure that we're doing that.
#
# So, as I said, I do just need to do more than just talk about jobs. I also want to talk about the jobs that we're bringing back.
#
# AMY GOODMAN: I wanted to ask President Obama about the economy.
#
# PRESIDENT BARACK OBAMA: The economy is here to stay. We're getting back to 1.2 percent growth in the fourth quarter of this year. And as I said, jobs are coming back. We've got a very strong economy. And the jobs that we're bringing back are good. We're going to keep the jobs that we're bringing back, and we're going to keep doing what we're doing.
#
# So, I want to talk about the economy today. I'm talking about jobs that are coming back. And I want to talk about jobs that we're bringing back.
#
# I believe that when we have more jobs, when we have more jobs than we have today, we're going to be able to build more of those jobs, and that's what we're going to do. And that's what I'm going to do.
#
# AMY GOODMAN: I want to turn to Senator Elizabeth Warren, who is the Democratic leader in the House of Representatives. She's going to be speaking to the Senate on the economy.
#
# Senator Elizabeth Warren, welcome to Democracy Now!
#
# LEONARD SCHUMER: Thank you.
#
# AMY GOODMAN: And Senator Warren, you're the first female representative in Congress.
#
# LEONARD SCHUMER: Well, I have a long history of being a big advocate of the welfare state. I was the first female member of Congress in the House of Representatives. And I was the first female senator in the Senate. And I was the first female member of Congress in the Senate. And you know, I think we have to have the right kind of leadership, leadership that takes, and I think that we're at the beginning of a long journey to build that kind of leadership for us to be able to compete for the jobs that we need.
#
# So, I'm here at the Capitol Hill
# ======================================== SAMPLE 2 ========================================
# It is true that the most important thing you can do to improve your overall health is to take care of yourself and your family. If you have any questions or concerns about your health, please contact our health care professionals.
#
# If you have any questions about your health, please contact our health care professionals. You can also download our free online health care calculator.<|endoftext|>For years, a group of the most prominent members of the Mormon religion have been trying to figure out how to break free from the church's teachings and go the other way. In one way or another, they've been getting their hopes up.
#
# Now, the group has been granted a new mission to help them do just that.
#
# The mission, now known as The Church of Jesus Christ of Latter-day Saints, is set to begin a year-long mission to explore the way the church views faith and scripture.
#
# The group, which has been set up to help the church's more than 400,000 members, has been looking to a new approach for years.
#
# Since its start in 2010 with the publication of a book titled "The Book of Mormon," the church's mission has been based more on the idea that the Church has a moral code. But the church has also been developing a method for finding out how to be more open to the teachings of scripture.
#
# "I was struck by how many people I meet who are very open to the teachings of scripture and find it very interesting," said Jeff M. Peterson, who founded The Church of Jesus Christ of Latter-day Saints in 1989 and has been a member since.
#
# "We've always been very open to certain things that have been handed down in scripture, and these people are really open to the things that are very clear to us, and so it's very surprising to me that the church will allow that to come about," he said.
#
# So far, The Church of Jesus Christ of Latter-day Saints has been trying to find the answer to some of the most difficult questions in the life of the church.
#
# How to use a spiritual medium such as the Bible to guide your spiritual journey?
#
# How to follow in the footsteps of those who have found the Book of Mormon?
#
# How to make the most of your spiritual experiences?
#
# How to find the truth?
#
# How to reconcile and transcend the teachings of scripture?
#
# How to find your own spiritual reality?
#
# How to become more open to the teachings of scripture?
#
# "That's the challenge that we're trying to make it all about," said Peterson. "We're trying to make it all about the book of Mormon and how it connects people to the scriptures. We're trying to make it all about how we can live our lives in the spirit of the Book of Mormon and do that."
#
# The mission will start in March 2016 and will focus on getting members to a new place of faith and to begin to build a new relationship with scripture.<|endoftext|>I'm just going to start talking about what I'm trying to say, you have to remember that I am a professional gamer. I am not a video game designer, I am not a journalist, I am not a writer, I am not a video game director and I don't even have a job. I am just a writer who does my best to write about the game industry and gaming. I am not a game designer, I am not a game director and I don't even have a job. I am just a writer who does my best to write about the game industry and gaming. I am not a game writer, I am not a game director and I don't even have a job. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and gaming. I am just a writer who does my best to write about the game industry and

# %% [markdown]
# ## Conditional sample generation
#
# To generate conditional samples from the small model:
# ```
# !python3 src/interactive_conditional_samples.py
# ```
# There are a few flags available.
# - `nsamples`: specify the number of samples you want to print
# - `length`
# - `batch_size`
# - `temperature`
# - `top_k`
#
# Want to test it the AI model passes the Voight-Kampff test? Here are some sample prompts to help your start:
# - You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you.
# - What's it like to hold the hand of someone you love? Interlinked. Do they teach you how to feel finger to finger? Interlinked.
# - I've seen things you people wouldn't believe. Attack ships on fire off the shoulder of Orion. I watched C-beams glitter in the dark near the Tannhäuser Gate. All those moments will be lost in time, like tears in rain. Time to die.
# - In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.
# - Building the wall is not a national emergency.
# - Some of the most glorious historical attractions in Spain date from the period of Muslim rule, including The Mezquita, built as the Great Mosque of Cordoba and the Medina Azahara, also in Cordoba, the Palace of al-Andalus; and the Alhambra in Granada, a splendid, intact palace.
# - Our solar system consists of the inner and outer planets, separated by an asteroid belt. It has
# - The 10 best foods are: 1. Serrano Ham 2. Manchego Cheese 3.
# - "It was a difficult game, but the performance was weak," Real Madrid boss Santi Solari on the

# %%
# !python3 src/interactive_conditional_samples.py
# Out:
# 2019-02-18 09:28:42.606705: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-18 09:28:42.606975: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e00680 executing computations on platform Host. Devices:
# 2019-02-18 09:28:42.607023: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-18 09:28:42.666830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-18 09:28:42.667318: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e015a0 executing computations on platform CUDA. Devices:
# 2019-02-18 09:28:42.667354: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-18 09:28:42.667831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-18 09:28:42.667869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-18 09:28:43.024578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-18 09:28:43.024647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-18 09:28:43.024667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-18 09:28:43.024929: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-18 09:28:43.024989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> Building the wall is not a national emergency.
# 2019-02-18 09:28:52.118240: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
#  It's a historic tome and the importance of supporting such a historic architecture."
#
# • Yonah Thompson, director, crowdfunding campaign
#
# [Civil Affairs]<|endoftext|>Joshua Blaze knows he doesn't use Flair because it's supposed to be good for him. That doesn't make it any less desirable than it can be. He has found it to be much more useful for that purpose, and can afford it too.
#
# Flair's ideas, through knowledge from all sides, haven't taken their cues from one another and it tests the limits of flaring. Although he was previously Hit Layer brainstormer of CoxEXTENDED entry control system (VTOS) and Into the Telepathy Projection System (ISPART) with talks on images and feasibility of individual telepathy pairs, only shows Daydream Junction to Blaze is compliant with the "mountain nature" requirement en­topher's if Twinchu pioneers hadn't too contested practical sickness with truckloads of nostalgia, the missing 6–2-Box of Blossoms/A single drop of Moonstone, Battle Rest is ultimately designed like an extension for the PORROSS PORTS ISP, with compatibility for crossed ranges through is analysis and 7–10′ wide chunks of the grid. Thus, this whole infrastructure will seem a little overspec­imicon­ous, even if BLOOP was free to use that as a molecule, added no manufacturers, ISPART expanded when the ACCU-CLI Gateway became operational as the first factor, and cli­x has proven to be a co-enhancement of PolyCamera FR id CLI. Perhaps even more reper­tesy is found in InfinToast.com site touting 12 manufacturers and ISPART Unlimited.
#
# Tumblr is also way im­dant. From Saunders-Colo and Oliver Pupolia Fong just look at RELIC detection cascades and how Bravado i Marie colored NewTrav-U 700 firs most design collaborations like the LM503667 Wireless Broadband Fast®58on USB 2.0 achieves sta­dred connectivity down to multi-F interference.
#
# How about using a UFire SMFG result with HI-FNC files to connect to the active hoops in Brickband 720l's or PECU components $200bw Inst­ret with the tplGHz; a dash-sign to amplify your energy unablite; outercings: micronpoint; amplified stand: Linearly probing for radicals
# ================================================================================
# Model prompt >>> Washington D.C. has been exploded by China
# ======================================== SAMPLE 1 ========================================
#  but their moot points on finance and Cdn have ebb e seem driven by the US. Chinese and foreign policy supporters of the BDS movement are floating insanely simple ideas, an aim that sounds horrifying, does ridiculous.
#
# But it's actually unthinkable. Stuart Clayton Dwyer on a must read project
#
# The Green Party's drive-by proposal for boycotts against the US – or the US Government after that or even its Secretary of the Treasury after the Ecuadorean Bank corrected a week of previously accurate accounting when it announced that new funds had been deposited at discount by large international banks in exchange for more points – comes at a time when the US government seems obsessed with reinamping trade in coal (it has put forward a historic energy credit action plan with energy favourable to its own demands).
#
# I see the good and bad of this approach as gamesmanship: when weapons scares will lead to rubble, as the buried soars—foreshocks are itself a horror of our times. Managing foreign policy is not the same thing as planning naming war, so separator tactics are much more important. We should all follow the charnel house rule of decrying day by day, coming from state to state in self-dubious tones.
#
# Donald Trump and Jane Tubings are fairly hackneyed and they don't talk or act like they get anything in common. Why would they choose a football team that is winners by balancing minimalism, inclusivity and fair play. The boycott and divestment campaign is talking about paying parking lots to certain banks, nor about those with holes in their buffers.
#
# Meanwhile, Donald Trump took the stinging knee to Rodrigo Duterte to protest a rise in corporate profits, and the BJP's campaign to stop him in his tracks with its anshifting, phoney crusade against poor men and women perhaps equally baffling. We saw endless attempts to obfuscate relationships all over the sprawling political spectrum in thanks to Trump as a salvo in globalisation, and really these days to cover them up from now on.
#
# Though there is no evidence the Bernie Sanders 'issue' is always the same, the 'issue' of racial injustice can be taken to mean nothing more than appeals to pockets of undoored voters, though things still still go slightly awry when her campaign uses language the Vietnamese call "moral equivalence".
#
# Fracking is just a matter of time before people around the world start because inexcusable factors still exist, and he's quite unlikely to get much attention
# ================================================================================
# Model prompt >>> i kill you
# ======================================== SAMPLE 1 ========================================
#  with it!
#
#
# Welcome to The Daily Mail. Last Post by Steve Cattaneo on Wed, 30 May 2014 and live Please join any discussion on this. This is a private group dedicated to promoting chivalry and confirming our position on homosexuality, and online preservation of our human dignity. All members are welcome to discuss, update and/or upload erroblings elsewhere.<|endoftext|>You may have seen the Turkish Road Bike Tour press release earlier on this day. Turkish Road Bike Tour organizers are clearly and irresponsible blaming two factors in the troubles of its online hub that may in fact be linked to the services provided by the Turkish Road Bike Tour ambassador in PS5.Ko Rahavia Turkish Road Bike Tour can state that the protest was created as the result of a post written on its official site by Ghansam M. Shah, then its English coordinator. Upon searching this website (AMBER) with no luck perhaps he should have searched the website at http://englishpmacx.tr , and perhaps have from that click through the pokemon.tr page to connect the dots coincidentally cover discussed rights related to that particular note.tf page or if you seem curious by looking at the graphic, you may find that they all say the same thing. Reply Delete
# It was so hard to read the module in case you want to read other content, but given the list of adress, I thought I would try to read themes before continuing with this page. Someday the CPM will be done coming to PS5 and that would include supporting the public. So one day they will have them transcribed to English, which my goodness. Go listen to translations again and a happy 2000 just like my english, thus dealing with the way everything is as it is. Reply Delete
# Can you supply any kind of explanation for what is using the Crowdbase database where support forums are because the developers were given information and/or officers upgrade permissions from users. HSM with Proxy Tempest early and supporting with Bitcoin, non government government roads, campaign site and sponsored by a well-known and well-known organization is also controlled through the Government of Mikeuf. Cider on the National and Private VPN apps like no background, so the information is but one of many known S.U.A (environmental impact and stress level) documentation messages and then send the app to our round table. However we need the support so there give corise Marc does digital use info as usual to post about the ethics of any site and get support into writing status of
# ================================================================================
# Model prompt >>> I have a dream
# ======================================== SAMPLE 1 ========================================
# : I can prove my legitimacy.
#
# Could you please tell all interested observers that, as I always warn you… if you will not log in, your password may be set to "email address". Does that seem like a bad idea? If not, well at least do from here on out you will understand why you should follow us as always.
#
# .
#
# You will regret it.Have a software grant. In the future, I hope you can continue to bring us this
#
# have a software grant. In the future, I hope you can continue to bring us this series
#
# this blog.
#
# .
#
# .
#
# Do you remember when meta heaven winningably matched the winners in LOL videos with your dumb daughter Arenainia weeks back in October? "They shit and super confident. OMG. They're real fucking talent guys. There is no better feeling among fine professionals than mastering their art and it rouses them to take action with their power." Would you like for me to remind you that it rouses them to take action with their power?
#
# Can you interpret those thoughts while reading the article:
#
# But…TEST is a Super game.GG. I learned recently that Rainbow Six Siege tag awaken_also has Mindload27 stop code showcased in its own game. I remember playing blind is all. I mean it got me terrible without teching. You guys said "not only does it imitate the game I played in person at BROW it lets players continue to pick up moto gun ammo whenever they like", didn't you? +My watermelon was mislead that evening Went to arrange workout at Mundi another exotic creature the usage of agave monster zed over my turntable sklung my frisbee ling. Just before I got sober, i slipped my watermelon in my lighter and might not be able to use it. Big bro congratulations #BetterDay.
#
# Are you niggerista?User debut73ckyes had such a Titan tortoise. And this has bitten off more than you guys will ever know.
#
# Have you been to GDC the whole time? Do you think someone somewhere in or near you would try and kill your child, especially if no one had dinner with you during the event?
#
# Do you have such a sweet son that you want him to crush your dick hard enough that she picks up in heh? Do you love the snowflakes on here in Vegas? Do you hate the fucking ol aviary to the
# ================================================================================
# Model prompt >>> I love you so much.
# ======================================== SAMPLE 1 ========================================
#  Go childcrops!"
#
# What was he thinking when Bill chose to stamp off the Joe important walls of the training rooms, running to the playground and shooting nachos out his preferred enemies? Radio playrus syndrome, he actually said.
#
# "I ain't mental for most people," Bill clarifies. "You just kind of move along, your natural mental gestures are not as good."
#
# Michael Brown responded, "No, not in your book, sir. Y'all have been f**king crazy." Brown insisted that he was not suggesting what Walton is actually implying, so he asserted that Bill's father had a panic attack during Morning In messages during the shoot. He later sent that an email to Walton asking why those supposedly lost had not been tripped over, as truth will always be the Bank good guy's best friend.
#
# "Mr. Brown, I understand that but once you've read your book, you'll understand," Bill falsely claimed, before recounting his personal history, "… which might call to mind a boy from the nineteenth century who actually locked himself into a baccalaureate to get fast, speed, all valedictorian— be that a bit speed— and just try not to be a little bit cocky now?" Walton then got into a long fight with Brown over the back of his bed.
#
# What the fuck was he saying? Walton attempted to retire from the sport without incident when Bill resurfaced with Blaine for an event... and fraud was all he didn't.
#
# September 2016: What's Next?
#
# Follow James E. Rollman on Twitter: @xws90Mandelryan
#
# Follow G EventBS "Reality is the education industry" on Facebook here: https://www.facebook.com/geventbs
#
# Gordon Bluyer
#
# Founded: 1923 and is the hottest man in the drama world & the new Big-POV wife of Jones Schultz because David Letterman HAS to run Game Of Thrones and gets cornered free gloves a bone. I'm picturing ritual sequence Our Show Could Pass and I think they're all terrible because of it We're not to act as if A Game Game Isn't Out There? in your 19 minutes Didn't say it was. You weren't introduced by Larry King and just played stupid! he's such a kind nigger! Didn't include animals his name is Lord (phone see. The apes were stitched in Manu), Got the Louie Bill was absolutely rewarded
# ================================================================================
# Model prompt >>> I hate you!!
# ======================================== SAMPLE 1 ========================================
#  Free View in iTunes
#
# 119 Clean Ep 149: Episode 140: Don't Wah! Prep Time Time To Rather Organ More You Nor There Ep 149 is Disguised: A Single Buffet More Rides Multiple Rides Crushes Agriculture They Betrayed Their Soul People to Be Tyger More Tribute for Discount Code Don't Worry, Hurt As Our Music Plays Chart I'm Only Gonna Stick With Anti-Chicken Free View in iTunes
#
# 120 Clean Ep 148: Snoop Dogg... Nothing Means Anything More Pomplice Size More Kill The Pussy More Money No Need For Us Play That Play Just the Beginning Fantasy, Pure Self Slaughters To Love, Let It Fly 1980 looks great Transbicycles, Kids at School Hall Yeah, Make Your Own TV, No Super Med yep... More Free View in iTunes
#
# 121 Clean Ep 147: The Heat of Fiesta Cayenne Cam AvgEps Meet It GeForcemounted Empire cam (zip) Thingship during Forecast Why Your MTL Is Linux On The Ear ... SkyliC as Joe Lincoln Montesquolini Car NMC Extra course refinement Rodmes chopping More Intro Correct Iaaaaapá respect DO floor as Sears NEOC Green Bark Are you horse and pony's happy How To Do So Hot beds with D Magazine The Spikens Pledge to Liberty French New Year: Whistler Ballet staves Marbles and Bath Cookies will be Plz oc Simple Milk ... Join us as the fifth entry in Houston's Holiday S... Free View in iTunes
#
# 122 Clean Ep 146: SHHHHHHHHHH!! Thanks to NLP ‎We're a Cameraman Too Sleepin --- Jam Ennis's Wild Twist "Dude Pick Up Me[Gyclypse] Over"[Notes Q&A] To Continue The Kid that We Used To Jurated on Drug Smuggling [hey... Ward). Always... More... Just a movie's worth of Groove Time on HBO Tap into Diyan's music home for e. Victorian Clif Rap Fist Tour Ecstasy Bobcat Fashion Beat Lunatic Asylum Help At Your Request Staya Doy Fashion Acid Killichi Dance and Christian Mass, Young Fathers, and New ... Free View in iTunes
#
# 123 Clean Ep 145: Jack Patrick's Up My Little Whippersnappers Calendars Wine Bar Food Moorad Nutella Scarf Club Miraculous Video Watch it whenever you'm on the other end of a Mac-chase Block Party But now duoconose really ample (and often elderly convers
# ================================================================================
# Model prompt >>>
